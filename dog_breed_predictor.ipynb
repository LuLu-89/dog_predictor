# %%
# Dependencies 
from IPython.display import Image, SVG
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import keras
from keras.preprocessing import image
from keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)
# Out:
# Using TensorFlow backend.

# %%
# Define image size
image_size = (224, 224)

# %%
# Bring in images
import os

image_path = os.path.join("Affenpinscher_233.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
# Model
model = VGG19(include_top=True, weights='imagenet')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0905 20:13:58.316508 140081445783424 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...
# 574717952/574710816 [==============================] - 6s 0us/step

# %%
 # Preprocess image for model prediction
# This step handles scaling and normalization for VGG19

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Make predictions

predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# Predicted: [[('n02110627', 'affenpinscher', 0.9415015), ('n02086240', 'Shih-Tzu', 0.017382398), ('n02112706', 'Brabancon_griffon', 0.01155008)]]

# %%
# Refactor above steps into reusable function
def predict(image_path):
    """Use VGG19 to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3))

# %%
image_path = os.path.join("Kai_02.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02108089', 'boxer', 0.49421328), ('n02093428', 'American_Staffordshire_terrier', 0.13778493), ('n02093256', 'Staffordshire_bullterrier', 0.12569173)]]

# %%
image_path = os.path.join("Samson_04.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02099712', 'Labrador_retriever', 0.34471378), ('n02093256', 'Staffordshire_bullterrier', 0.1965184), ('n02104365', 'schipperke', 0.110569134)]]

# %%
image_path = os.path.join("Chihuahua_2973.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02085620', 'Chihuahua', 0.9205061), ('n02108915', 'French_bulldog', 0.026434494), ('n02123597', 'Siamese_cat', 0.0039185653)]]

# %%
image_path = os.path.join("Labrador_retriever_57.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02107142', 'Doberman', 0.29793596), ('n02099267', 'flat-coated_retriever', 0.20005946), ('n02099712', 'Labrador_retriever', 0.08666339)]]

# %%
image_path = os.path.join("Samson_02.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02808440', 'bathtub', 0.35536686), ('n04493381', 'tub', 0.24767944), ('n02099267', 'flat-coated_retriever', 0.16589873)]]

# %%
image_path = os.path.join("Samson_07.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02099712', 'Labrador_retriever', 0.5480229), ('n02099267', 'flat-coated_retriever', 0.12318521), ('n02104365', 'schipperke', 0.0962418)]]

# %%
image_path = os.path.join("Kai_03.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02444819', 'otter', 0.56100994), ('n02909870', 'bucket', 0.08905991), ('n02077923', 'sea_lion', 0.063009515)]]

# %%
image_path = os.path.join("Kai_04.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02091467', 'Norwegian_elkhound', 0.24416134), ('n02105162', 'malinois', 0.18424852), ('n02110806', 'basenji', 0.1585295)]]

# %%
image_path = os.path.join("Boxer_69.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02108089', 'boxer', 0.5071498), ('n02108422', 'bull_mastiff', 0.45820576), ('n02087394', 'Rhodesian_ridgeback', 0.024748433)]]

# %%
image_path = os.path.join("Pembroke_209.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02113023', 'Pembroke', 0.9777092), ('n02113186', 'Cardigan', 0.01662592), ('n02105855', 'Shetland_sheepdog', 0.0017808666)]]

# %%
image_path = os.path.join("American_Staffordshire_terrier_1482.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02093256', 'Staffordshire_bullterrier', 0.48979402), ('n02093428', 'American_Staffordshire_terrier', 0.36436048), ('n02087394', 'Rhodesian_ridgeback', 0.041278847)]]

# %%
image_path = os.path.join("Kai_lion.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02483362', 'gibbon', 0.1958328), ('n02085620', 'Chihuahua', 0.18884116), ('n02112018', 'Pomeranian', 0.16349325)]]

# %%
image_path = os.path.join("Samson_panda.jpg")
predict(image_path)
# Out:
# Predicted: [[('n04229816', 'ski_mask', 0.10622395), ('n02096585', 'Boston_bull', 0.047559462), ('n02104365', 'schipperke', 0.040579155)]]

# %%
image_path = os.path.join("Kai_05.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02107312', 'miniature_pinscher', 0.35627484), ('n02085620', 'Chihuahua', 0.24544978), ('n02093754', 'Border_terrier', 0.1350961)]]

# %%
image_path = os.path.join("Labrador_retriever_209.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02099712', 'Labrador_retriever', 0.9074473), ('n02099601', 'golden_retriever', 0.062581204), ('n02089867', 'Walker_hound', 0.0077119004)]]

# %%
image_path = os.path.join("aussie.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02106030', 'collie', 0.3027333), ('n02102177', 'Welsh_springer_spaniel', 0.14592586), ('n02106166', 'Border_collie', 0.10450615)]]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-53d1176b-f71f-483f-8db8-90fe0c56d311" name="files[]" multiple disabled />
#      <output id="result-53d1176b-f71f-483f-8db8-90fe0c56d311">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pembroke_209.jpg to Pembroke_209 (1).jpg
# User uploaded file "Pembroke_209.jpg" with length 37410 bytes
